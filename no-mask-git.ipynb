# %%
% cd /content/drive/My\ Drive/Colab\ Notebooks/no-mask
# Out:
# /content/drive/My Drive/Colab Notebooks/no-mask

# %%
! git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 2690 (delta 0), reused 0 (delta 0), pack-reused 2685
# Receiving objects: 100% (2690/2690), 5.44 MiB | 10.61 MiB/s, done.
# Resolving deltas: 100% (1777/1777), done.

# %%
# !git init
# !git config --global user.email davidalford678@gmail.com
# !git config --global user.name 5starkarma

from getpass import getpass
password = getpass('Password:')
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Colab Notebooks/no-mask/.git/
# Password:··········

# %%
# !rm -rf .git/index.lock

# %%
# !git pull origin main
# Out:
# From https://github.com/5starkarma/no-mask
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git remote add origin https://5starkarma:$password@github.com/5starkarma/no-mask.git

# %%
! git rm -f --cached yolov5
# Out:
# rm 'yolov5'

# %%
# !git add configs/ scripts/
# Out:
# ^C

# %%
# !git push origin main -f
# Out:
# Everything up-to-date

# %%
# !git commit -m "Initial commit"

# !git branch -M main

# !git push -u origin main

# !git branch
# Out:
# [main 9ef3135] Initial commit
#  1 file changed, 1 insertion(+)
#  create mode 160000 yolov5
# Counting objects: 2, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 277 bytes | 69.00 KiB/s, done.
# Total 2 (delta 0), reused 0 (delta 0)
# To https://github.com/5starkarma/no-mask.git
#    f6af1f7..9ef3135  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# * main
